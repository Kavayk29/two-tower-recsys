# %% [markdown]
# # Two-Tower Recommendation System Kaggle Runner
# This notebook will clone the repository, install dependencies, and run the complete training pipeline including data processing and MLflow tracking.

# %%
# !git clone https://github.com/YOUR_USERNAME/two-tower-recsys.git
# %cd two-tower-recsys

# %%
# !pip install -r requirements.txt

# %%
# !python -m src.data.download

# %%
# !python -m src.data.preprocess

# %%
# !python -m src.data.features

# %%
# !python -m src.training.trainer

# %%
# !python build_index.py

# %% [markdown]
# Training metrics were logged with MLflow during the run above. To view them locally (not on Kaggle), run `mlflow ui` from the repo root and open http://localhost:5000.
